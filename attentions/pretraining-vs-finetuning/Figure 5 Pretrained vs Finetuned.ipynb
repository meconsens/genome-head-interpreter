# %% [markdown]
# # Code for Figure 5 Pre-training vs. Fine-tuning
#
# Make sure to upload all the explanation_prompts jsons for every model at the same level as this notebook when running.

# %%
import json
import textwrap
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %% [markdown]
# Find important features:

# %%
# load and parse jsons
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# extract and process features from the JSON explanations
def process_features(data):
    results = {}
    all_features = []
    for layer, layer_data in data.items():
        sentences = layer_data['sentences'][0]
        numeric_features = [f for f in sentences if isinstance(f, list) and len(f) == 2 and isinstance(f[1], int)]
        positive = sorted(numeric_features, key=lambda x: x[1], reverse=True)[:5]
        negative = sorted(numeric_features, key=lambda x: x[1])[:5]
        results[layer] = {'positive': positive, 'negative': negative}
        all_features.extend(numeric_features)
    return results, all_features

#find overall top 10 features
def get_overall_top_features(all_features):
    feature_scores = defaultdict(int)
    for feature in all_features:
        feature_scores[feature[0]] += feature[1]
    sorted_features = sorted(feature_scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_features[:10], sorted_features[-10:]

def analyze_models(files):
    all_results = {}
    for file_name in files:
        print(file_name)
        data = load_json(file_name)
        per_head_features, all_features = process_features(data)
        overall_top_positive, overall_top_negative = get_overall_top_features(all_features)
        all_results[file_name] = {
            'per_head': per_head_features,
            'overall_positive': overall_top_positive,
            'overall_negative': overall_top_negative,
        }
    return all_results

# JSON files to analyze
files = [
    'DNABERT_pretrained.json',
    'DNABERT_random_init.json',
    'DNABERT_random.json',
    'DNABERT.json',
    'enformer.json',
    'enformer_random_init.json',
    'scgpt_ms_pretrained.json',
    'scgpt_ms_random_init.json',
    'scgpt_ms.json', 'scgpt_pancreas_pretrained.json', 'scgpt_pancreas.json',
    'scgpt_pancreas_random_init.json'
]


model_results = analyze_models(files)

for model, features in model_results.items():
    print(f"Model: {model}")
    if(re.match("DNABERT",model)):
      total_heads = 144
    if (re.match("enformer", model)):
      total_heads = 88
    if (re.match("scgpt", model)):
      total_heads = 96
    print("Overall Top 10 Positive Features:", features['overall_positive'])
    print("Overall Top 10 Negative Features:", features['overall_negative'])
    print("\n")
# Out:
# DNABERT_pretrained.json
# DNABERT_random_init.json
# DNABERT_random.json
# DNABERT.json
# enformer.json
# enformer_random_init.json
# scgpt_ms_pretrained.json
# scgpt_ms_random_init.json
# scgpt_ms.json
# scgpt_pancreas_pretrained.json
# scgpt_pancreas.json
# scgpt_pancreas_random_init.json
# Model: DNABERT_pretrained.json
# Overall Top 10 Positive Features: [('DM-type intertwined zinc finger factors', 298), ('Basic leucine zipper factors (bZIP)&SAND domain factors', 258), ('Nuclear receptors with C4 zinc fingers', 246), ('Basic leucine zipper factors (bZIP)', 226), ('Other C4 zinc finger-type factors&Basic helix-loop-helix factors (bHLH)', 180), ('repeat_DNA', 168), ('TEA domain factors', 140), ('Heteromeric CCAAT-binding factors', 120), ('Heat shock factors', 119), ('SAND domain factors', 116)]
# Overall Top 10 Negative Features: [('Grainyhead domain factors', -99), ('T-Box factors', -99), ('Rel homology region (RHR) factors', -99), ('Basic helix-span-helix factors (bHSH)', -108), ('Tryptophan cluster factors', -123), ('TSS', -154), ('repeat_SINE', -172), ('C2H2 zinc finger factors', -175), ('GCM domain factors', -189), ('repeat_Simple_repeat', -234)]
#
#
# Model: DNABERT_random_init.json
# Overall Top 10 Positive Features: [('repeat_LINE', 321), ('repeat_LTR', 182), ('Basic leucine zipper factors (bZIP)', 97), ('Homeo domain factors', 56), ('Other C4 zinc finger-type factors', 55), ('TATA-binding proteins', 28), ('CRC domain', 27), ('repeat_DNA', 25), ('Fork head/winged helix factors', 20), ('High-mobility group (HMG) domain factors', 10)]
# Overall Top 10 Negative Features: [('Rel homology region (RHR) factors', -10), ('Homeo domain factors&Paired box factors', -27), ('GCM domain factors', -30), ('TEA domain factors', -97), ('repeat_SINE', -116), ('SMAD/NF-1 DNA-binding domain factors', -119), ('C2H2 zinc finger factors', -325), ('GC', -344), ('Basic helix-span-helix factors (bHSH)', -405), ('TSS', -659)]
#
#
# Model: DNABERT_random.json
# Overall Top 10 Positive Features: [('Rel homology region (RHR) factors', 87), ('TEA domain factors', 74), ('Tryptophan cluster factors', 72), ('Heat shock factors', 66), ('repeat_LINE', 61), ('Nuclear receptors with C4 zinc fingers', 51), ('Basic leucine zipper factors (bZIP)', 42), ('STAT domain factors', 41), ('Heteromeric CCAAT-binding factors', 33), ('DM-type intertwined zinc finger factors', 30)]
# Overall Top 10 Negative Features: [('Paired box factors', -11), ('Basic helix-span-helix factors (bHSH)', -13), ('Homeo domain factors&Paired box factors', -14), ('MADS box factors', -14), ('Basic helix-loop-helix factors (bHLH)', -19), ('C2H2 zinc finger factors', -22), ('repeat_Simple_repeat', -23), ('SAND domain factors', -28), ('repeat_SINE', -34), ('TSS', -69)]
#
#
# Model: DNABERT.json
# Overall Top 10 Positive Features: [('Basic leucine zipper factors (bZIP)&SAND domain factors', 253), ('Basic leucine zipper factors (bZIP)', 185), ('ARID', 158), ('TEA domain factors', 156), ('Homeo domain factors&High-mobility group (HMG) domain factors', 136), ('Nuclear receptors with C4 zinc fingers', 135), ('CRC domain', 132), ('TATA-binding proteins', 129), ('ARID&Homeo domain factors', 126), ('Homeo domain factors', 125)]
# Overall Top 10 Negative Features: [('Basic helix-loop-helix factors (bHLH)', -67), ('GC', -68), ('Basic helix-span-helix factors (bHSH)', -90), ('repeat_Simple_repeat', -98), ('C2CH THAP-type zinc finger factors', -118), ('C2H2 zinc finger factors', -136), ('GCM domain factors', -148), ('Rel homology region (RHR) factors', -170), ('TSS', -217), ('Tryptophan cluster factors', -264)]
#
#
# Model: enformer.json
# Overall Top 10 Positive Features: [('promoters', 10), ('TSS', 10), ('CRISPR_perturbation', 10), ('enhancers', 10)]
# Overall Top 10 Negative Features: [('promoters', 10), ('TSS', 10), ('CRISPR_perturbation', 10), ('enhancers', 10)]
#
#
# Model: enformer_random_init.json
# Overall Top 10 Positive Features: [('repeat_LINE', 33), ('C2H2 zinc finger factors', 28), ('repeat_LTR', 27), ('Basic helix-span-helix factors (bHSH)', 25), ('GC', 20), ('SMAD/NF-1 DNA-binding domain factors', 20), ('repeat_SINE', 1), ('Basic leucine zipper factors (bZIP)&SAND domain factors', -1), ('DM-type intertwined zinc finger factors', -10), ('MADS box factors', -10)]
# Overall Top 10 Negative Features: [('Fork head/winged helix factors', -19), ('ARID', -26), ('CRC domain', -26), ('ARID&Homeo domain factors', -27), ('Homeo domain factors', -27), ('TATA-binding proteins', -31), ('promoters', -40), ('enhancers', -42), ('CRISPR_perturbation', -56), ('repeat_Retroposon', -58)]
#
#
# Model: scgpt_ms_pretrained.json
# Overall Top 10 Positive Features: [('GOBP regulation of cell differentiation', 124), ('GOCC intrinsic component of plasma membrane', 121), ('GOBP tissue development', 118), ('GOBP biological adhesion', 111), ('GOBP cellular response to endogenous stimulus', 104), ('GOBP transmembrane transport', 99), ('GOBP positive regulation of multicellular organismal process', 97), ('expression', 96), ('GOBP positive regulation of cellular biosynthetic process', 96), ('GOBP positive regulation of RNA metabolic process', 96)]
# Overall Top 10 Negative Features: [('GOCC membrane protein complex', -36), ('lung proliferating macrophage cell', -41), ('GOBP establishment of protein localization', -46), ('GOBP intracellular transport', -48), ('GOBP proteolysis', -52), ('lung proximal ciliated cell', -54), ('ovary CL8 mature cumulus granulosa cell', -57), ('GOMF ribonucleotide binding', -61), ('GOCC mitochondrion', -90), ('GOCC envelope', -99)]
#
#
# Model: scgpt_ms_random_init.json
# Overall Top 10 Positive Features: [('GOBP regulation of protein modification process', 174), ('GOBP vesicle mediated transport', 159), ('GOBP protein containign complex organization', 154), ('expression', 153), ('GOBP chemical homeostasis', 139), ('GOBP cellular macromolecule localization', 135), ('GOBP neuron differentiation', 131), ('gastric immune cells', 119), ('GOBP cellular response to stress', 117), ('GOBP neuron development', 116)]
# Overall Top 10 Negative Features: [('GOBP circulatory system development', -75), ('midbrain neuotype human pericytes', -77), ('GOBP regulation of cell population proliferation', -82), ('GOBP regulation of cell death', -85), ('GOBP cell migration', -88), ('GOBP locomotion', -89), ('GOBP regulation of cell differentiation', -94), ('GOBP positive regulation of developmental process', -104), ('GOBP tissue development', -105), ('GOBP regulation of multicellular organismal development', -126)]
#
#
# Model: scgpt_ms.json
# Overall Top 10 Positive Features: [('GOCC intrinsic component of plasma membrane', 201), ('GOBP anatomical structure formation involved in morphogenesis', 186), ('GOBP circulatory system development', 181), ('GOBP reproduction', 173), ('GOBP tissue development', 156), ('GOBP regulation of multicellular organismal development', 155), ('GOBP positive regulation of multicellular organismal process', 154), ('GOBP locomotion', 152), ('GOBP cell migration', 149), ('GOBP regulation of cell differentiation', 148)]
# Overall Top 10 Negative Features: [('GOBP proteolysis', -52), ('GOBP organonitrogen compound biosynthetic process', -61), ('GOCC envelope', -65), ('GOBP cytoskeleton organization', -71), ('GOBP cellular macromolecule localization', -87), ('GOBP protein containign complex organization', -88), ('GOCC mitochondrion', -94), ('ovary CL8 mature cumulus granulosa cell', -107), ('lung proliferating macrophage cell', -116), ('lung proximal ciliated cell', -170)]
#
#
# Model: scgpt_pancreas_pretrained.json
# Overall Top 10 Positive Features: [('GOBP proteolysis', 135), ('GOMF molecular function regulator', 133), ('GOBP biological adhesion', 122), ('GOBP response to cytokine', 121), ('GOBP positive regulation of gene expression', 121), ('expression', 112), ('midbrain neurotype human pericyte', 105), ('GOBP regulation of transport', 103), ('GOBP response to oxygen containing compound', 102), ('GOBP locomotion', 101)]
# Overall Top 10 Negative Features: [('GOCC plasma membrane region', 27), ('GOMF molecular transducer activity', 27), ('fetal cerebellum vascular endothelial cells', 20), ('GOCC intrinsic component of plasma membrane', -8), ('GOBP cytoskeleton organization', -19), ('midbrain neurotypes human microglial cell', -23), ('GOMF transcription regulator activity', -75), ('GOBP cell cycle', -83), ('lung proliferating macrophage cell', -110), ('GOMF sequence specific DNA binding', -112)]
#
#
# Model: scgpt_pancreas.json
# Overall Top 10 Positive Features: [('GOBP positive regulation of signaling', 211), ('lung proliferating macrophage cell', 179), ('GOBP cell activation', 178), ('GOBP locomotion', 157), ('GOBP positive regulation of gene expression', 152), ('GOBP regulation of cell population proliferation', 150), ('GOBP positive regulation of multicellular organismal process', 145), ('GOBP regulation of anatomical structure morphogenesis', 142), ('GOBP regulation of cellular component movement', 141), ('midbrain neurotype human pericyte', 137)]
# Overall Top 10 Negative Features: [('GOCC plasma membrane region', 36), ('GOBP cell cell adhesion', 33), ('pancreas ductal cell', 28), ('pancreas acinar cell', 20), ('GOBP cellular response to stress', 13), ('GOBP reproduction', 11), ('GOMF molecular transducer activity', -22), ('GOBP cell cycle', -47), ('GOMF transcription regulator activity', -60), ('GOMF sequence specific DNA binding', -62)]
#
#
# Model: scgpt_pancreas_random_init.json
# Overall Top 10 Positive Features: [('pancreas acinar cell', 126), ('GOBP enzyme linked receptor protein signaling pathway', 106), ('GOBP tube morphogenesis', 104), ('GOBP circulatory system development', 96), ('GOBP vasculature development', 96), ('GOBP tube development', 94), ('GOBP positive regulation of gene expression', 93), ('GOBP positive regulation of multicellular organismal process', 89), ('GOBP response to oxygen containing compound', 85), ('GOBP ion transport', 84)]
# Overall Top 10 Negative Features: [('GOBP reproduction', -63), ('GOBP cell activation', -66), ('fetal cerebellum vascular endothelial cells', -75), ('GOBP response to lipid', -78), ('GOBP neurogenesis', -79), ('GOMF signaling receptor binding', -79), ('GOBP regulation of cell population proliferation', -83), ('GOBP neuron differentiation', -114), ('GOBP small molecule metabolic process', -117), ('GOBP cell projection organization', -124)]

# %% [markdown]
# Code for plotting:

# %%
import matplotlib.colors as mcolors

#wrap text to fit into the heatmap cells if plotting with text
def wrap_text(text, width=15):
    wrapped_text = text.replace('_', '\n')
    return '\n'.join(['\n'.join(textwrap.wrap(line, width)) for line in wrapped_text.split('\n')])

#features based on word
def process_features(data, word):
    word_features = defaultdict(list)
    cumulative_positive = 0
    cumulative_negative = 0
    total_heads = 0
    for layer, layer_data in data.items():
        sentences = layer_data['sentences'][0]
        for feature in sentences:
            if isinstance(feature, list) and len(feature) == 2 and isinstance(feature[1], (int, float)) and re.match(f".*{word}.*",feature[0]):
                word_features[layer].append(feature)
                if feature[1] > 0:
                    cumulative_positive += 1
                elif feature[1] < 0:
                    cumulative_negative += 1
        total_heads += len(layer_data['sentences'][0])
    return word_features, cumulative_positive, cumulative_negative, total_heads

#subplots
def create_subplot(features, title, word, num_layers, num_heads, split_term):
    data = np.zeros((num_layers, num_heads))
    annotations = np.full((num_layers, num_heads), '', dtype=object)

    for layer, items in features.items():
        layer_idx = int(layer.split('layer')[1].split(split_term)[0])
        head_idx = int(layer.split('head')[1])
        for feature in items:
            data[layer_idx, head_idx] = feature[1]
            annotations[layer_idx, head_idx] = wrap_text(feature[0], width=10)

    return data, annotations

def analyze_and_visualize_models(files, word):
    all_data = []
    results = []
    all_annotations = []
    for file_name in files:
        data = load_json(file_name)
        word_features, cum_positive, cum_negative, total_heads = process_features(data, word)
        normalized_positive = (cum_positive / total_heads) * 100
        normalized_negative = (cum_negative / total_heads) * 100
        if re.match('scgpt.*', file_name):
          num_heads = 8
          num_layers = 12
          split_term = "_"
          figure_size = (50,10)
        if re.match('enformer.*', file_name):
           num_heads = 8
           num_layers = 11
           split_term = "-"
           figure_size = (50, 10)
        if re.match('DNABERT.*', file_name):
           num_heads = 12
           num_layers = 12
           split_term = "-"
           figure_size=(50, 10)
        data, annotations = create_subplot(word_features, file_name, word, num_layers, num_heads,split_term)
        all_data.append(data)
        all_annotations.append(annotations)
        results.append((normalized_positive, normalized_negative))

    global_min = min(data.min() for data in all_data)
    global_max = max(data.max() for data in all_data)

    fig, axs = plt.subplots(1, len(files), figsize=figure_size)
    for idx, (data, annot, result) in enumerate(zip(all_data, all_annotations, results)):
        file_name = files[idx]
         # Define a diverging colormap with grey at zero
        norm = mcolors.TwoSlopeNorm(vmin=global_min, vcenter=0, vmax=global_max)
        sns.heatmap(data, ax=axs[idx], cmap='coolwarm', cbar=True, norm=norm, fmt="", vmin=global_min, vmax=global_max)
        #code to annotate feature names on the squares in heatmap
        #sns.heatmap(data, ax=axs[idx], annot = annot, cmap='coolwarm', cbar=True, fmt="", vmin=global_min, vmax=global_max)
        axs[idx].set_title(f'{file_name.split("/")[-1]} - "{word}"\nNorm Pos: {result[0]:.2f}, Norm Neg: {result[1]:.2f}')
        axs[idx].set_xlabel('Head Index')
        axs[idx].set_ylabel('Layer Index')


    plt.tight_layout()
    plt.show()

# %% [markdown]
# Figure 5 for scGPT models:

# %%
files = [
    'scgpt_ms_pretrained.json',
    'scgpt_ms_random_init.json',
    'scgpt_ms.json', 'scgpt_pancreas_pretrained.json', 'scgpt_pancreas_random_init.json','scgpt_pancreas.json'
]
#for figure = pancreas
feature_word = 'immun.*'
analyze_and_visualize_models(files, feature_word)

# %% [markdown]
# For DNABERT and enformer models:

# %%
files = [
    'DNABERT_pretrained.json',
    'DNABERT_random.json',
    'DNABERT_random_init.json',
    'DNABERT.json',
    'enformer.json',
    'enformer_random_init.json'
]

# for figure:
feature_word = 'repeat.*'
analyze_and_visualize_models(files, feature_word)
